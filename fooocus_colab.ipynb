# %% [markdown]
# <a href="https://colab.research.google.com/github/KacoERL/fooocusNud/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Checkpoint Realista compatível com SDXL (RealVisXL V4.0)
# !wget -O /content/Fooocus/models/checkpoints/RealVisXL_V4.safetensors "https://civitai.com/api/download/models/361593"
# LoRA NudeXL (Corrigido com .safetensors)
# !wget -O /content/Fooocus/models/loras/nudeXL.safetensors "https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/14770/nudexl.iqUR.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22NudeXL.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20251127/us-east-1/s3/aws4_request&X-Amz-Date=20251127T174433Z&X-Amz-SignedHeaders=host&X-Amz-Signature=7ee18ccf6b3dd89892d41a29e3b58ed66b7c686c1c1f25fe738ef683924793c9"
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# --2025-11-27 19:13:32--  https://civitai.com/api/download/models/361593
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/26957/realvisxlV40.oFmv.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22realvisxlV50_v40LightningBakedvae.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20251127/us-east-1/s3/aws4_request&X-Amz-Date=20251127T191332Z&X-Amz-SignedHeaders=host&X-Amz-Signature=cf515acdb01e86d1b62f87ebbea6964e6fea2f5fdae12800c10afbccf7b80d4a [following]
# ...
