# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# LoRa Innies: Better vulva v1.1
# !wget -O /content/Fooocus/models/loras/Innies_Better_vulva.safetensors "https://civitai.com/api/download/models/12873"

# Instala aria2 (mais rápido e confiável para downloads grandes no Colab)
# !apt -y install -qq aria2

# Cria as pastas se não existirem
# !mkdir -p /content/Fooocus/models/upscale_models
# !mkdir -p /content/Fooocus/models/inpaint

# Baixa o upscaler (fooocus_upscaler_s409985e5.bin ~32MB)
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" \
  -d /content/Fooocus/models/upscale_models -o fooocus_upscaler_s409985e5.bin

# Baixa o inpaint head (pequeno, ~51kB)
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/fooocus_inpaint_head.pth" \
  -d /content/Fooocus/models/inpaint -o fooocus_inpaint_head.pth

# Baixa o inpaint patch principal (inpaint_v26.fooocus.patch ~1.23GB)
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/inpaint_v26.fooocus.patch" \
  -d /content/Fooocus/models/inpaint -o inpaint_v26.fooocus.patch

# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# --2026-02-19 19:13:08--  https://civitai.com/api/download/models/12873
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/156479/model/innievag.5SUu.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22innievag.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20260219/us-east-1/s3/aws4_request&X-Amz-Date=20260219T191309Z&X-Amz-SignedHeaders=host&X-Amz-Signature=77ec80c215f562f266a8d99ba4a0bb56e82ff5f9edfc94b099a928e978cfa525 [following]
# ...
