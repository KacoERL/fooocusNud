# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Checkpoint Merge >Base Model (SDXL only) > LustifySDXL version: OLT INPAITING
# !wget -O /content/Fooocus/models/checkpoints/LustifySDXL.safetensors "https://civitai.com/api/download/models/1588039?token=fce2fe69353887c356f4520dd9f8d2f6"

# LoRA NudeXL 1.0 / Weight 0.8
# !wget -O /content/Fooocus/models/loras/nudeXL.safetensors "https://civitai.com/api/download/models/243570?token=fce2fe69353887c356f4520dd9f8d2f6"
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# --2025-12-04 11:32:50--  https://civitai.com/api/download/models/1588039?token=fce2fe69353887c356f4520dd9f8d2f6
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# ...
