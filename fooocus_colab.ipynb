# %% [markdown]
# <a href="https://colab.research.google.com/github/KacoERL/fooocusNud/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# prompt: photorealistic 8k, A captivating full-body portrait of a stunning nude woman, mid-30s, striking a confident and sensual pose, looking directly at the camera. Highly detailed skin texture, subtle glistening sweat, soft rim lighting accentuating the curves. Deep depth of field, cinematic quality, taken with a Canon R5, 85mm lens, f/1.4, professional photography. Intimate studio setting with a dark, blurred background.

# Checkpoint Merge >Base Model (SDXL only) > LustifySDXL version: OLT INPAITING
# !wget -O /content/Fooocus/models/checkpoints/LustifySDXL.safetensors "https://civitai.com/api/download/models/1588039"
# LoRA NudeXL 1.0 / Weight 0.8
# !wget -O /content/Fooocus/models/loras/nudeXL.safetensors "https://civitai.com/api/download/models/243570"

# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 61.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.19.0
#     Uninstalling pygit2-1.19.0:
#       Successfully uninstalled pygit2-1.19.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6730 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 35.28 MiB/s, done.
# Resolving deltas: 100% (3847/3847), done.
# /content/Fooocus
# --2025-12-04 00:13:52--  https://civitai.com/api/download/models/1588039
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
